# %% [markdown]
# <h1> Global Terrorist Incident Heatmap</h1>
# <h2> Analyst: Francis Raven Salamo <h2>

# %%
# !pip install folium
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <h2> Importing libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import folium
from folium.plugins import HeatMap

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2> Import dataframe

# %%
terror = pd.read_csv('jup\\Global_terrorist.csv', encoding='ISO-8859-1')

# %%
terror
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# <h1>INSIGHTS</h1>

# %% [markdown]
# <h1>Example provided</h1>

# %%
filtered_data = terror[(terror['region_txt'] == 'Middle East & North Africa') & 
                     (terror['iyear'] >= 2000) & 
                     (terror['attacktype1_txt'] == 'Bombing/Explosion') & 
                     (terror['nkill'] > 10)]

aggregated_data = filtered_data.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')

aggregated_data['normalized_weight'] = (aggregated_data['incident_count'] - aggregated_data['incident_count'].min()) / \
                                       (aggregated_data['incident_count'].max() - aggregated_data['incident_count'].min())

heat_data = aggregated_data[['latitude', 'longitude', 'normalized_weight']].values.tolist()

m = folium.Map(location=[30, 40], zoom_start=4)

HeatMap(heat_data).add_to(m)

m.save('terrorism_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1> Insight 1 </h1>
#
#
# <h2>"Where have assassination incidents been most concentrated in South America since 1980?"</h2>
#
#
# <h3> This analysis generates a heatmap that visualizes the geographical distribution of assassination-related terrorist incidents in South America from 1980 onward. </h3>

# %%
filtered_df = terror[(terror['region_txt'] == 'South America') &(terror['iyear'] >= 1980) &(terror['attacktype1_txt'] == 'Assassination')]

aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
aggregated_df['normalized_weight'] = ((aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) /(aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min()))

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
assasinate = folium.Map(location=[-15, -60], zoom_start=3)
HeatMap(heat_data).add_to(assasinate)
assasinate.save('assasinate.html')
assasinate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1> Insight 2 </h1>
#
#
# <h2>"How have bombing and explosion incidents been distributed across different locations in North America since 1990, and where are the areas with the highest concentration of such attacks?"</h2>
#
#
# <h3> The generated map visualizes key areas in North America where bombings or explosions have taken place since 1990. Locations with a higher number of incidents are shown with greater brightness and density on the map. </h3>

# %%
filtered_df = terror[(terror['region_txt'] == 'North America') &(terror['iyear'] >= 1990) &(terror['attacktype1_txt'] == 'Bombing/Explosion')]

aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
aggregated_df['normalized_weight'] = ((aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) /(aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min()))

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
c4 = folium.Map(location=[40, -90], zoom_start=4)
HeatMap(heat_data).add_to(c4)
c4.save('c4.html')
c4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1> Insight 3 </h1>
#
#
# <h2>""What are the geographic hotspots of armed assault incidents in Germany?""</h2>
#
#
# <h3> This visualization highlights areas in Germany with higher frequencies of armed assault attacks, providing valuable insight for understanding violence patterns and supporting security planning. </h3>

# %%
filtered_df = terror[(terror['country_txt'] == 'Germany')&(terror['attacktype1_txt'] == 'Armed Assault')]

aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
aggregated_df['normalized_weight'] = ((aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) /(aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min()))

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
assault = folium.Map(location=[53, 10], zoom_start=5)
HeatMap(heat_data).add_to(assault)
assault.save('assault.html')
assault
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1> Insight 3 </h1>
#
#
# <h2>"Where have high-fatality hostage-taking incidents occurred most frequently in the Middle East and North Africa?"</h2>
#
#
# <h3> This heatmap visualizes the geographic concentration of deadly hostage-taking incidents in the Middle East and North Africa region. </h3>

# %%
filtered_df = terror[(terror['region_txt'] == 'Middle East & North Africa') & (terror['attacktype1_txt'] == 'Hostage Taking (Kidnapping)') & (terror['nkill'] >= 5)]

aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
aggregated_df['normalized_weight'] = ((aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) /(aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min()))

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
host = folium.Map(location=[30, 40], zoom_start=4)
HeatMap(heat_data).add_to(host)
host.save('host.html')
host
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1> Insight 5</h1>
#
#
# <h2>"Where in the United States have facility attacks targeting educational institutions been most frequent?"</h2>
#
#
# <h3> This heatmap highlights the geographic distribution of attacks on educational facilities in the United States. </h3>

# %%
filtered_df = terror[(terror['country_txt'] == 'United States') & (terror['attacktype1_txt'] == 'Facility/Infrastructure Attack') & (terror['targsubtype1_txt'] == 'School/University/Educational Building') ]

aggregated_df = filtered_df.groupby(['latitude', 'longitude']).size().reset_index(name='incident_count')
aggregated_df['normalized_weight'] = ((aggregated_df['incident_count'] - aggregated_df['incident_count'].min()) /(aggregated_df['incident_count'].max() - aggregated_df['incident_count'].min()))

heat_data = aggregated_df[['latitude', 'longitude', 'normalized_weight']].values.tolist()
pum = folium.Map(location=[30, 40], zoom_start=4)
HeatMap(heat_data).add_to(pum)
pum.save('pum.html')
pum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
